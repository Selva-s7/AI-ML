# %%
import pandas as pd


data = {
    'product': ['Apple', 'Banana', 'Apple', 'Mango', 'Banana'],
    'price':   ['100', '50', '100', '200', '50'],
    'rating':  [4.5, 3.2, 4.5, 4.8, 3.2],
    'stock':   [10, 20, 10, 5, None]
}
df = pd.DataFrame(data)

# Bug 1
print(df['price'].mean())

# Bug 2
df.drop_duplicates()
print(df.shape)  # Expected: (3, 4)

# Bug 3
df['stock'] = df['stock'].astype(int)

# Bug 4
print(df.duplicated(subset='product', keep='first').sum())
# Expected: number of duplicate products
