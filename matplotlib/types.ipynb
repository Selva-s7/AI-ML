# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)
print(df.info())
# 1. Line plot — plot average fare per class
#    x = class (1,2,3), y = mean fare
#    Add title, xlabel, ylabel, grid, marker
plt.figure(figsize=(8,4))
line1=df.groupby('Pclass')['Fare'].mean() *100
plt.plot(line1.index,line1.values,marker='o')
plt.title('AVERAGE FARE PER PCLASS')
plt.xlabel('CLASS')
plt.ylabel('AVG FARE')
plt.legend()
plt.grid(True)
plt.show()
# 2. Bar plot — number of passengers per embarkation port
#    S, C, Q — use different color for each bar
#    Rename xticks to 'Southampton', 'Cherbourg', 'Queenstown'
bar1=df.groupby('Embarked')['PassengerId'].count()
plt.figure(figsize=(8,4))
plt.bar(bar1.index,bar1.values,color=['red','blue','green'])
plt.title('NO OF PASSENGERS PER PORT')
plt.xlabel('PORTS')
plt.ylabel('NO OF PASSENGERS')
plt.xticks(['S','C','Q'],['Southampton','Cherbourg','Queenstown'])
plt.show()
# 3. Histogram — distribution of Fare
#    bins=40, color='green'
#    Add a vertical line at mean fare:
#    plt.axvline(df['Fare'].mean(), color='red', linestyle='--', label='Mean')
plt.figure(figsize=(8,4))
plt.hist(df['Fare'],bins=40,color='green')
plt.axvline(df['Fare'].mean(), color='red', linestyle='--', label='Mean')
plt.show()

# 4. Scatter — Age vs Fare
#    Color by Pclass (c=df['Pclass'])
#    cmap='viridis', alpha=0.6
plt.figure(figsize=(8,4))
plt.scatter(df['Age'],df['Fare'],c=df['Pclass'],cmap='viridis',alpha=0.6)
plt.show()
# 5. Create a 2x2 subplot with:
#    [0,0] Age histogram
#    [0,1] Survivors by gender bar plot
#    [1,0] Age vs Fare scatter
#    [1,1] Average fare per class line plot
#    tight_layout, proper titles on all
figs,axes=plt.subplots(2,2,figsize=(12,8))
axes[0,0].hist(df['Age'].dropna(),bins=40,color='yellow')
axes[0,0].set_title('AGE HISTOGRAM')
sg=df.groupby('Sex')['Survived'].sum()
axes[0,1].bar(sg.index,sg.values,color=['red','pink'])
axes[0,1].set_title('SURVIVORS')
axes[1,0].scatter(df['Age'],df['Fare'],c=df['Pclass'],cmap='viridis')
axes[1,0].set_title('AGE VS FARE BASED ON CLASS')
ac=df.groupby('Pclass')['Fare'].mean()*100
axes[1,1].plot(ac.index,ac.values,marker='o',color='red')
axes[1,1].set_title('AVG FARE PER CLASS')
plt.tight_layout()
plt.show()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
# None
# C:\Users\selva\AppData\Local\Temp\ipykernel_17240\2102269890.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...
