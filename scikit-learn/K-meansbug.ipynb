# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

X, _ = make_blobs(n_samples=200, centers=4, random_state=42)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

kmeans = KMeans(n_clusters=4, random_state=42,n_init=10)   # bug 1 - missing n_init
kmeans.fit(X_scaled)

print("Labels:", kmeans.labels_)
print("Centroids:", kmeans.cluster_centers_)
print("Inertia:", kmeans.inertia_)
print("Cluster of first point:", kmeans.labels_[0])  # bug 2 - should be index 0
# Out:
# Labels: [0 1 3 3 2 2 0 3 0 2 2 0 0 2 2 2 1 3 2 2 2 2 3 1 3 1 1 2 1 0 2 2 3 3 1 0 3
#  0 3 1 2 1 2 2 3 0 0 2 0 1 3 1 3 0 1 1 2 2 1 0 3 0 2 3 3 2 0 1 3 1 1 3 1 2
#  0 2 0 1 2 1 1 0 2 3 3 3 3 1 0 3 2 1 0 0 0 3 1 0 2 1 3 3 1 2 1 0 3 2 2 3 0
#  2 1 3 1 3 3 1 1 1 3 2 0 3 3 0 1 0 0 1 2 2 1 3 3 0 2 2 1 2 0 1 3 0 0 1 0 3
#  2 2 1 3 0 3 2 3 3 0 0 0 1 0 0 3 1 2 0 0 2 0 3 1 2 2 0 2 0 1 1 2 1 2 3 3 3
#  1 0 0 0 1 1 2 3 3 1 3 0 1 2 0]
# Centroids: [[ 1.53948194 -0.11961465]
#  [ 0.13560922  0.96145781]
#  [-0.64528482 -1.56418144]
#  [-1.02980634  0.72233829]]
# Inertia: 11.378346920622075
# Cluster of first point: 0
