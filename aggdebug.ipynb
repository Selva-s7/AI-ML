# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# Bug 1

result=df.groupby('Pclass')['Age'].mean()
#print(result)

# Bug 2
print(df.groupby('Sex')['Survived'].agg(['mean', 'sum']))

# Bug 3
print(df.groupby(['Pclass', 'Sex'])['Survived'].mean() * 100)

# Bug 4
print(df.groupby('Embarked').agg({'Fare':'mean','Age':'mean'}))
# Out:
#             mean  sum
# Sex
# female  0.742038  233
# male    0.188908  109
# Pclass  Sex
# 1       female    96.808511
#         male      36.885246
# 2       female    92.105263
#         male      15.740741
# 3       female    50.000000
#         male      13.544669
# Name: Survived, dtype: float64
#                Fare        Age
# Embarked
# C         59.954144  30.814769
# Q         13.276030  28.089286
# S         27.079812  29.445397
