# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)
print(df.shape)
print(df.isnull().sum()[df.isnull().sum()>0])
print(df.isnull().sum()[df.isnull().sum()>0].count())
df['Age']=df['Age'].fillna(df['Age'].median())
df=df.drop('Cabin',axis=1)
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])
print(df.columns.to_list())
print(df[df['Pclass']==1])
print(df[df['Pclass']==2])
print(df[(df['Age']>18) & (df['Age']<30)][['Name','Age','Survived']])
df[df['Survived']==1][['Name','Age','Survived']]


print((df[(df['Pclass']==1)&(df['Survived']==1)].shape[0])/(df[df['Pclass']==1].shape[0]))
print((df[(df['Pclass']==3)&(df['Survived']==1)].shape[0])/(df[df['Pclass']==3].shape[0]))
sur=df[df['Survived']==1].shape[0]
d=df[~(df['Survived']==1)].count().shape[0]
s=pd.Series([sur,d],index=['Survived','Died'])

# 1. How many rows and columns?
# 1. How many rows and columns?

# 2. Which columns have missing values and how many?

# 3. Clean the data:
#    - Fill Age with median
#    - Drop Cabin
#    - Fill Embarked with mode

# 4. How many passengers were in each class?
#    (use boolean indexing — one line per class)

# 5. Select only Name, Age, Survived columns
#    for passengers aged between 18 and 30
#    who survived

# 6. What % of first class passengers survived?
#    What % of third class passengers survived?
#    (use boolean indexing)

# 7. Create a Series of survival counts
#    index = ['Survived', 'Died']
#    values = actual counts from the data
# Out:
# (891, 12)
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64
# 3
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked']
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ...
