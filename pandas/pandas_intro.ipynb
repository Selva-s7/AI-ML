# %%
import pandas as pd

# %%
marks=pd.Series([100,99,98],index=["RUDRA","SELVA","ADHI"])
print(marks)
print(type(marks))
print(marks.shape)
print(marks.ndim)
# Out:
# SELVA        100
# KEERTHANA     99
# HARISHMA      98
# dtype: int64
# <class 'pandas.Series'>
# (3,)
# 1

# %%
data = {
    'name':   ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'marks':  [85, 92, 78, 95, 60],
    'passed': [True, True, True, True, False],
    'grade':  ['A', 'A', 'B', 'A', 'C']
}
df = pd.DataFrame(data)
print(df.describe())
df=pd.DataFrame(data)
print(df)
print(type(df))
print(df.shape)
print(df.describe(include='all'))
# Out:
#            marks
# count   5.000000
# mean   82.000000
# std    13.946326
# min    60.000000
# 25%    78.000000
# 50%    85.000000
# 75%    92.000000
# max    95.000000
#       name  marks  passed grade
# 0    Alice     85    True     A
# 1      Bob     92    True     A
# 2  Charlie     78    True     B
# 3    Diana     95    True     A
# 4      Eve     60   False     C
# <class 'pandas.DataFrame'>
# (5, 4)
#          name      marks passed grade
# count       5   5.000000      5     5
# unique      5        NaN      2     3
# top     Alice        NaN   True     A
# freq        1        NaN      4     3
# mean      NaN  82.000000    NaN   NaN
# std       NaN  13.946326    NaN   NaN
# min       NaN  60.000000    NaN   NaN
# 25%       NaN  78.000000    NaN   NaN
# 50%       NaN  85.000000    NaN   NaN
# 75%       NaN  92.000000    NaN   NaN
# max       NaN  95.000000    NaN   NaN
