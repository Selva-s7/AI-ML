# %%
import pandas as pd

# %%
data = {
    'player': ['Virat', 'Rohit', 'Dhoni', 'Bumrah', 'Jadeja'],
    'runs':   [700, 650, 400, 50, 200],
    'wickets':[2, 1, 0, 25, 15],
    'active': [True, True, False, True, True]
}

df = pd.DataFrame(data)

# Bug 1-correction: shape not shape()
print(df.shape)

# Bug 2-correction describe() not describe
print(df.describe())

# Bug 3 correction for 2D use DataFrame not series

s = pd.DataFrame({'marks':[700, 650, 400, 50, 200]})
print(s.shape)  # Expected: (5, 1)

# Bug 4
print(df.head(2))  # Expected: first 2 rows only
# Out:
# (5, 4)
#              runs    wickets
# count    5.000000   5.000000
# mean   400.000000   8.600000
# std    280.624304  11.013628
# min     50.000000   0.000000
# 25%    200.000000   1.000000
# 50%    400.000000   2.000000
# 75%    650.000000  15.000000
# max    700.000000  25.000000
# (5, 1)
#   player  runs  wickets  active
# 0  Virat   700        2    True
# 1  Rohit   650        1    True
