# %%
import pandas as pd

# %%
# Given this DataFrame
data = {
    'city':       ['Chennai', 'Mumbai', 'Delhi', 'Bangalore', 'Hyderabad'],
    'temp':       [38, 32, 41, 28, 35],
    'humidity':   [80, 75, 60, 70, 65],
    'rainfall':   [120, 200, 80, 150, 100],
    'is_coastal': [True, True, False, False, False]
}

df = pd.DataFrame(data)
print(df.shape)
print(df.describe())
print(df.describe(exclude='number'))
print(df)
s=pd.Series([38, 32, 41, 28, 35],index=['Chennai', 'Mumbai', 'Delhi', 'Bangalore', 'Hyderabad'])
print(s.shape)#(5,)

# 1. Print shape — how many cities and features?
# 2. Print only numeric column stats using describe()
# 3. Print only non-numeric stats using describe()
# 4. Which city has highest temp? (just use head/tail/print — no fancy methods yet so print whole dataframe)
# 5. Create a Series of just the temps with city names as index
# 6. What is shape of that Series?
# Out:
# (5, 5)
#             temp   humidity    rainfall
# count   5.000000   5.000000    5.000000
# mean   34.800000  70.000000  130.000000
# std     5.069517   7.905694   46.904158
# min    28.000000  60.000000   80.000000
# 25%    32.000000  65.000000  100.000000
# 50%    35.000000  70.000000  120.000000
# 75%    38.000000  75.000000  150.000000
# max    41.000000  80.000000  200.000000
#            city is_coastal
# count         5          5
# unique        5          2
# top     Chennai      False
# freq          1          3
#         city  temp  humidity  rainfall  is_coastal
# 0    Chennai    38        80       120        True
# 1     Mumbai    32        75       200        True
# 2      Delhi    41        60        80       False
# 3  Bangalore    28        70       150       False
# 4  Hyderabad    35        65       100       False
# (5,)
