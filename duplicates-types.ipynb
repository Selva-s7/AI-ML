# %%
import pandas as pd

# %%
data = {
    'student': ['Alice', 'Bob', 'Alice', 'Charlie', 'Bob', 'Diana'],
    'subject': ['Math', 'Math', 'Math', 'Science', 'Science', 'Science'],
    'marks':   ['95', '80', '95', '70', '85', '90'],
    'grade':   ['A', 'B', 'A', 'C', 'B', 'A']
}
df = pd.DataFrame(data)
print(df.dtypes)
df['marks']=df['marks'].astype(int)
print(df.duplicated().sum())
print(df[df.duplicated()])
df=df.drop_duplicates()
print(df.shape[0])
print(df['marks'].mean())
print(df.isnull().sum())

# 1. Check and print all dtypes
# 2. Convert marks to integer
# 3. How many duplicate rows exist?
# 4. Show the duplicate rows
# 5. Remove duplicates — how many rows remain?
# 6. After removing duplicates, what is mean marks?
# 7. How many null values exist per column?
# Out:
# student    str
# subject    str
# marks      str
# grade      str
# dtype: object
# 1
#   student subject  marks grade
# 2   Alice    Math     95     A
# 5
# 84.0
# student    0
# subject    0
# marks      0
# grade      0
# dtype: int64
